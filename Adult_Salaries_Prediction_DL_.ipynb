# %% [markdown]
# ## Import the Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Read the data

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Data Science/adult salaries/adult_train.csv')

# %%
test_data = pd.read_csv('/content/drive/MyDrive/Data Science/adult salaries/adult_test.csv')

# %%
train_data.head()
# Out:
#    age          workclass  Unnamed: 2   education  education-num  \
# 0   39          State-gov       77516   Bachelors             13
# 1   50   Self-emp-not-inc       83311   Bachelors             13
# 2   38            Private      215646     HS-grad              9
# 3   53            Private      234721        11th              7
# 4   28            Private      338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# ...

# %% [markdown]
# ## Information about the data

# %%
train_data['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
train_data['capital-loss'].unique()
# Out:
# array([   0, 2042, 1408, 1902, 1573, 1887, 1719, 1762, 1564, 2179, 1816,
#        1980, 1977, 1876, 1340, 2206, 1741, 1485, 2339, 2415, 1380, 1721,
#        2051, 2377, 1669, 2352, 1672,  653, 2392, 1504, 2001, 1590, 1651,
#        1628, 1848, 1740, 2002, 1579, 2258, 1602,  419, 2547, 2174, 2205,
#        1726, 2444, 1138, 2238,  625,  213, 1539,  880, 1668, 1092, 1594,
#        3004, 2231, 1844,  810, 2824, 2559, 2057, 1974,  974, 2149, 1825,
#        1735, 1258, 2129, 2603, 2282,  323, 4356, 2246, 1617, 1648, 2489,
#        3770, 1755, 3683, 2267, 2080, 2457,  155, 3900, 2201, 1944, 2467,
#        2163, 2754, 2472, 1411])

# %%
train_data = train_data.drop(['Unnamed: 2','education-num','marital-status','relationship','race','sex'], axis = 1,inplace = False)

# %%
test_data = test_data.drop(['Unnamed: 2','education-num','marital-status','relationship','race','sex'], axis = 1,inplace = False)

# %%
train_data_obj = train_data.select_dtypes(include ='object').columns

# %%
test_data_obj = test_data.select_dtypes(include ='object').columns

# %%
label_encoder = LabelEncoder()
for col in train_data_obj:
  train_data[col] = label_encoder.fit_transform(train_data[col])

# %%
label_encoder = LabelEncoder()
for col in train_data_obj:
  test_data[col] = label_encoder.fit_transform(test_data[col])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   education       32561 non-null  int64
#  3   occupation      32561 non-null  int64
#  4   capital-gain    32561 non-null  int64
#  5   capital-loss    32561 non-null  int64
#  6   hours-per-week  32561 non-null  int64
#  7   native-country  32561 non-null  int64
#  8   Income          32561 non-null  int64
# dtypes: int64(9)
# memory usage: 2.2 MB

# %%
train_data.head()
# Out:
#    age  workclass  education  occupation  capital-gain  capital-loss  \
# 0   39          7          9           1          2174             0
# 1   50          6          9           4             0             0
# 2   38          4         11           6             0             0
# 3   53          4          1           6             0             0
# 4   28          4          9          10             0             0
#
#    hours-per-week  native-country  Income
# 0              40              39       0
# 1              13              39       0
# 2              40              39       0
# 3              40              39       0
# 4              40               5       0

# %%
train_data.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# occupation        0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16281 non-null  int64
#  1   workclass       16281 non-null  int64
#  2   education       16281 non-null  int64
#  3   occupation      16281 non-null  int64
#  4   capital-gain    16281 non-null  int64
#  5   capital-loss    16281 non-null  int64
#  6   hours-per-week  16281 non-null  int64
#  7   native-country  16281 non-null  int64
#  8   Income          16281 non-null  int64
# dtypes: int64(9)
# memory usage: 1.1 MB

# %%
test_data.head()
# Out:
#    age  workclass  education  occupation  capital-gain  capital-loss  \
# 0   25          4          1           7             0             0
# 1   38          4         11           5             0             0
# 2   28          2          7          11             0             0
# 3   44          4         15           7          7688             0
# 4   18          0         15           0             0             0
#
#    hours-per-week  native-country  Income
# 0              40              38       0
# 1              50              38       0
# 2              40              38       1
# 3              40              38       1
# 4              30              38       0

# %%
test_data.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# occupation        0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
train_data.corr()
# Out:
#                      age  workclass  education  occupation  capital-gain  \
# age             1.000000   0.003787  -0.010508   -0.020947      0.077674
# workclass       0.003787   1.000000   0.023513    0.254892      0.033835
# education      -0.010508   0.023513   1.000000   -0.021260      0.030046
# occupation     -0.020947   0.254892  -0.021260    1.000000      0.025505
# capital-gain    0.077674   0.033835   0.030046    0.025505      1.000000
# capital-loss    0.057775   0.012216   0.016746    0.017987     -0.031615
# hours-per-week  0.068756   0.138962   0.055510    0.080383      0.078409
# native-country -0.001151  -0.007690   0.064288   -0.012543     -0.001982
# Income          0.234037   0.051604   0.079317    0.075468      0.223329
#
#                 capital-loss  hours-per-week  native-country    Income
# age                 0.057775        0.068756       -0.001151  0.234037
# workclass           0.012216        0.138962       -0.007690  0.051604
# ...

# %% [markdown]
# ## Correlations between Features

# %%
correlation_matrix = train_data.corr()

# %%
train_data.columns
# Out:
# Index(['age', 'workclass', 'education', 'occupation', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'Income'],
#       dtype='object')

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='Greens' ,vmin=-0.5, vmax=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
train_data.head()
# Out:
#    age  workclass  education  occupation  capital-gain  capital-loss  \
# 0   39          7          9           1          2174             0
# 1   50          6          9           4             0             0
# 2   38          4         11           6             0             0
# 3   53          4          1           6             0             0
# 4   28          4          9          10             0             0
#
#    hours-per-week  native-country  Income
# 0              40              39       0
# 1              13              39       0
# 2              40              39       0
# 3              40              39       0
# 4              40               5       0

# %%
x_train = train_data.iloc[:,:8]

# %%
x_train
# Out:
#        age  workclass  education  occupation  capital-gain  capital-loss  \
# 0       39          7          9           1          2174             0
# 1       50          6          9           4             0             0
# 2       38          4         11           6             0             0
# 3       53          4          1           6             0             0
# 4       28          4          9          10             0             0
# ...    ...        ...        ...         ...           ...           ...
# 32556   27          4          7          13             0             0
# 32557   40          4         11           7             0             0
# 32558   58          4         11           1             0             0
# 32559   22          4         11           1             0             0
# 32560   52          5         11           4         15024             0
#
#        hours-per-week  native-country
# 0                  40              39
# ...

# %%
x_test = x_test = test_data.iloc[:,:8]

# %%
x_test
# Out:
#        age  workclass  education  occupation  capital-gain  capital-loss  \
# 0       25          4          1           7             0             0
# 1       38          4         11           5             0             0
# 2       28          2          7          11             0             0
# 3       44          4         15           7          7688             0
# 4       18          0         15           0             0             0
# ...    ...        ...        ...         ...           ...           ...
# 16276   39          4          9          10             0             0
# 16277   64          0         11           0             0             0
# 16278   38          4          9          10             0             0
# 16279   44          4          9           1          5455             0
# 16280   35          5          9           4             0             0
#
#        hours-per-week  native-country
# 0                  40              38
# ...

# %%
y_train = train_data['Income']

# %%
pd.DataFrame(y_train)
# Out:
#        Income
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 32556       0
# 32557       1
# 32558       0
# 32559       0
# 32560       1
#
# [32561 rows x 1 columns]

# %%
y_test = test_data['Income']

# %%
pd.DataFrame(y_test)
# Out:
#        Income
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
# ...       ...
# 16276       0
# 16277       0
# 16278       0
# 16279       0
# 16280       1
#
# [16281 rows x 1 columns]

# %% [markdown]
# ## Built the Neural Network Models

# %% [markdown]
# # Import the Keras and Tensorflow Library

# %%
import tensorflow as tf
import keras
from keras.layers import Input, Dense

# %%
print (f'x_train shape is' ,{x_train.shape },'\n',
       'x_test shape is ' ,{x_test.shape} ,'\n' ,
       'y_train shape is ' ,{y_train.shape} , '\n' ,
       'y_test shape is ',{y_test.shape})
# Out:
# x_train shape is {(32561, 8)}
#  x_test shape is  {(16281, 8)}
#  y_train shape is  {(32561,)}
#  y_test shape is  {(16281,)}

# %%
KerasModel = keras.models.Sequential([
            keras.layers.Input(shape= (8)),
            keras.layers.Dense(512 , activation = 'relu'),
            keras.layers.BatchNormalization(),
            # keras.layers.Dropout(0.1),
            keras.layers.Dense(512 , activation = 'relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Dropout(0.2),
            keras.layers.Dense(256, activation = 'relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Dropout(0.3),
            keras.layers.Dense(128 , activation = 'relu'),
            # keras.layers.Dropout(0.1),
            keras.layers.Dense(1 , activation = 'sigmoid'),
])

# %% [markdown]
# ## RMSprop Optimizer

# %%
# KerasModel.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
#                    loss='binary_crossentropy',
#                    metrics=['accuracy'])

# KerasModel.fit(x_train, y_train,
#                validation_data=(x_test, y_test),
#                epochs=300,
#                batch_size=128,
#                verbose=1,
#                callbacks=[tf.keras.callbacks.EarlyStopping(
#                    patience=50,
#                    monitor='val_accuracy',
#                    restore_best_weights=True)]
#                )

# %% [markdown]
# ## Adam Optimizer

# %%
KerasModel.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])
KerasModel = KerasModel.fit(x_train, y_train,
                            validation_data=(x_test, y_test),
                            epochs=300,  # Increase the number of epochs
                            batch_size=128,  # Adjust the batch size
                            verbose=1,
                            callbacks=[tf.keras.callbacks.EarlyStopping(
                                           patience=50,  # Increase the patience
                                           monitor='val_accuracy',
                                           restore_best_weights=True)]
                           )

# %% [markdown]
# ## SGD Optimizer

# %%
KerasModel.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

KerasModel.fit(x_train, y_train,
               validation_data=(x_test, y_test),
               epochs=300,
               batch_size=128,
               verbose=1,
               callbacks=[tf.keras.callbacks.EarlyStopping(
                   patience=50,
                   monitor='val_accuracy',
                   restore_best_weights=True)]
               )

# %% [markdown]
# ##ADAMAX Optimizer

# %%
KerasModel.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

KerasModel.fit(x_train, y_train,
               validation_data=(x_test, y_test),
               epochs=150,
               batch_size=256,
               verbose=1,
               callbacks=[tf.keras.callbacks.EarlyStopping(
                   patience=50,
                   monitor='val_accuracy',
                   restore_best_weights=True)]
               )

# %% [markdown]
# ##NADAM Optimizer

# %%
KerasModel.compile(optimizer=keras.optimizers.Nadam(learning_rate=0.001),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

history =KerasModel.fit(x_train, y_train,
               validation_data=(x_test, y_test),
               epochs=150,
               batch_size=256,
               verbose=1,
               callbacks=[tf.keras.callbacks.EarlyStopping(
                   patience=50,
                   monitor='val_accuracy',
                   restore_best_weights=True)]
               )

# %% [markdown]
# ## The Model Structure

# %%
KerasModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               4608
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 1)                 129
#
# ...
# Total params: 436737 (1.67 MB)
# Trainable params: 434177 (1.66 MB)
# Non-trainable params: 2560 (10.00 KB)
# ...

# %%
KerasModel.save('AdultSalaries.model')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ##TO Load The Model

# %%
# NewKerasModel = keras.models.load_model('DLChurn.model')
